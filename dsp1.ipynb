223504495554, 77.86122724289339],[16.248985251261185, 77.83933943579018],[16.196915384389573, 77.81529316447707],[16.09337068262592, 77.8358684500823],[15.915864033686782, 78.04591492560887],[15.832652127355777, 78.02948597340621],[15.55771816420356, 77.92720290376104],[15.393656108240434, 77.87370394736926],[15.387709769272067, 77.89428910969511],[15.385068875890017, 77.9135001868853],[15.370497097764936, 78.01713844537299],[15.422098624717997, 78.07272846887491],[15.503475707195978, 78.20387102385772],[15.49951032664879, 78.23201951069639],[15.463646868701838, 78.4901736002823],[15.432651364880066, 78.71119920142912],[15.37625829499642, 78.92194770038236]]

# %%
f1=folium.FeatureGroup("p1")
f2=folium.FeatureGroup("p2")
line1=folium.vector_layers.PolyLine(coords_1,popup='<b>Path of p1</b>',color='blue',tooltip='500km').add_to(f1)
line2=folium.vector_layers.PolyLine(coords_2,popup='<b>Path of p2</b>',color='red').add_to(f2)
f1.add_to(map)
f2.add_to(map)


folium.Marker(location=[16.78632563487666, 80.84735626125745],popup='<h3 style="color:green;">Marker3<h3>',tooltip='<b>START HERE</b>',icon=folium.Icon(color='red',icon='none')).add_to(map)
folium.Marker(location=[15.379816532218545, 78.92984508480194],popup='<h3 style="color:green;">Marker3<h3>',tooltip='<b>DESTINATION</b>',icon=folium.Icon(color='red',icon='none')).add_to(map)

folium.Marker(location=[16.790929728239902, 80.82247745928686],popup='<b>Marker2</b>',tooltip='RGUKT NUZVID',icon=folium.Icon(color='purple',prefix='fa',icon='university')).add_to(map)
folium.Marker(location=[16.67785771180285, 80.78039452969415],popup='<b>Marker2</b>',tooltip='car repair',icon=folium.Icon(color='lightgray',prefix='fa',icon='car')).add_to(map)
folium.Marker(location=[16.377296500435992, 80.52100328616571],popup='<b>Marker2</b>',tooltip='acahrya nagarguna',icon=folium.Icon(color='lightgray',prefix='fa',icon='university')).add_to(map)
folium.Marker(location=[16.297541621204264, 80.44159895043047],popup='<b>Marker2</b>',tooltip='guntur busstop',icon=folium.Icon(color='green',prefix='fa',icon='bus')).add_to(map)
folium.Marker(location=[16.144594168722918, 81.19460325311279],popup='<b>Marker2</b>',tooltip='machilipatnam port',icon=folium.Icon(color='purple',prefix='fa',icon='anchor')).add_to(map)
folium.Marker(location=[16.518731707518395, 80.61996027138099],popup='<b>Marker2</b>',tooltip='HANUMANJN',icon=folium.Icon(color='blue',prefix='fa',icon='subway')).add_to(map)
folium.Marker(location=[16.74245078524681, 81.08244364171752],popup='<b>Marker2</b>',tooltip='manipal hospotal',icon=folium.Icon(color='red',prefix='fa',icon='heartbeat')).add_to(map)
folium.Marker(location=[17.240437472049717, 78.42938510175829],popup='<b>Marker2</b>',tooltip='hyderabad airport',icon=folium.Icon(color='blue',prefix='fa',icon='plane')).add_to(map)
folium.Marker(location=[15.831439258644686, 78.03853488041639],popup='<b>Marker2</b>',tooltip='basha restaurant',icon=folium.Icon(color='blue',prefix='fa',icon='fa-cutlery')).add_to(map)
folium.Marker(location=[17.055787146305878, 79.27486495865597],popup='<b>Marker2</b>',tooltip='nalgonda busstop',icon=folium.Icon(color='green',prefix='fa',icon='bus')).add_to(map)
folium.LayerControl().add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...
